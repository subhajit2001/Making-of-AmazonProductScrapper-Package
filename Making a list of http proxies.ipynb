# %% [markdown]
# <h3>Opening the http_proxies.txt file using file pointer</h3>

# %%
fptr = open('http_proxies.txt','r')

# %% [markdown]
# <h3>Making a list of the proxies</h3>

# %%
array_list = []
for s in fptr:
    array_list.append(s.strip('\n'))

# %% [markdown]
# <h3>Visualizing the proxy list</

# %%
array_list
# Out:
# ['171.232.74.123:45006',
#  '144.91.66.128:3128',
#  '163.172.157.7:80',
#  '39.108.193.201:8888',
#  '167.71.199.228:8080',
#  '187.189.132.173:999',
#  '102.69.52.102:8080',
#  '112.6.117.178:8085',
#  '71.19.250.92:42162',
#  '103.101.100.27:8080',
#  '177.93.38.214:999',
#  '171.6.6.94:8000',
#  '77.70.35.87:37475',
#  '177.91.74.118:8080',
#  '183.89.163.227:8080',
#  '195.53.49.11:3128',
#  '103.159.46.14:82',
#  '202.57.55.242:45112',
#  '212.112.127.20:8080',
#  '220.135.165.38:8080',
#  '68.188.59.198:80',
#  '89.163.224.127:8088',
#  '18.138.230.74:3128',
#  '103.161.164.115:8181',
#  '103.159.243.130:83',
#  '36.94.2.138:8080',
#  '146.120.214.240:8080',
#  '103.47.64.85:8080',
#  '187.188.171.73:6969',
#  '82.165.252.82:80',
#  '80.93.212.44:3155',
#  '222.231.47.230:3128',
#  '190.109.6.115:999',
#  '190.60.71.124:80',
#  '203.158.167.25:8080',
#  '202.40.188.90:40486',
#  '103.107.94.2:52827',
#  '103.205.183.18:55443',
#  '27.131.179.197:10443',
#  '40.127.201.29:80',
# ...
